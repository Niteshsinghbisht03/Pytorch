# %% [markdown]
# <a href="https://colab.research.google.com/github/Niteshsinghbisht03/Pytorch/blob/main/Manual_Pytorch_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **important Libraries**

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # **Data Loading and Preprocessing**

# %%
#data loading
df = pd.read_csv("/content/breast-cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.shape
# Out:
# (569, 32)

# %%
df.drop(columns=['id'],inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,shuffle=True)

# %% [markdown]
# # **Train_Test Split**

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.05986724, -0.27177152, -0.01249657, ..., -0.6101971 ,
#         -0.43356359, -0.42418404],
#        [-0.91244669, -1.62605196, -0.94026455, ..., -1.26968925,
#         -1.21668301, -0.99959296],
#        [ 0.06857453, -0.58590874, -0.05115357, ..., -1.24854778,
#         -0.71631259, -1.2909181 ],
#        ...,
#        [-0.68025232, -0.62081287, -0.70580145, ..., -0.69567556,
#         -1.90131682, -0.60967404],
#        [-1.69349051,  0.31694489, -1.60709779, ..., -0.55711529,
#          0.65613199,  3.57749815],
#        [ 1.58944766, -0.10190473,  1.59597074, ...,  1.25603181,
#          0.09381094,  0.83079786]])

# %%
y_test.unique()
# Out:
# array(['B', 'M'], dtype=object)

# %%
le=LabelEncoder()

# %%
y_test=le.fit_transform(y_test)
y_train=le.transform(y_train)

# %%
y_test.shape
# Out:
# (114,)

# %%
X_train.shape
# Out:
# (455, 30)

# %% [markdown]
# # **Numpy array to Torch Tensor**

# %%
X_test_tensor=torch.from_numpy(X_test)
X_train_tensor = torch.from_numpy(X_train)
y_train_tensor = torch.from_numpy(y_train)
y_test_tensor = torch.from_numpy(y_test)

# %%
X_test.shape
# Out:
# (114, 30)

# %%
y_test.shape
# Out:
# (114,)

# %% [markdown]
# # **Defining a Model**

# %%
class mySimpleNN():
  #initialize the weights and bias
  def __init__(self,X):
    self.w=torch.rand(X.shape[1],1,requires_grad=True,dtype=torch.float64)
    self.b=torch.zeros(1,dtype=torch.float64,requires_grad=True)

  #Feed Forward Training
  def forward_pass(self,X):
    return torch.sigmoid(torch.matmul(X,self.w)+self.b)

  #loss calculation
  def loss(self,y_pred,y):
    epsilon = 1e-7
    y_pred = torch.clamp(y_pred,epsilon,1-epsilon)

    return -(y_train_tensor * torch.log(y_pred) + (1-y_train_tensor)*torch.log(1-y_pred)).mean()

# %% [markdown]
# # **Important Parameters**

# %%
#Learning Rate and number of Epochs
lr=0.1
epochs=300

# %% [markdown]
# # **Training Pipeline**

# %%
#create Model
model = mySimpleNN(X_train_tensor)

for epochs in range(epochs):
  #forward Prediciton
  y_pred = model.forward_pass(X_train_tensor)

  #loss calculation
  loss= model.loss(y_pred,y_train_tensor)

  #backpropogation
  loss.backward()

  #weight updation
  with torch.no_grad():
    model.w -= lr * model.w.grad
    model.b -= lr * model.b.grad


  model.w.grad.zero_()
  model.b.grad.zero_()

  print(f'epochs: {epochs+1 }  :  loss: {loss.item()}')
# Out:
# epochs: 1  :  loss: 3.8296637358189014
# epochs: 2  :  loss: 3.7144526237964555
# epochs: 3  :  loss: 3.5951723731499787
# epochs: 4  :  loss: 3.469478312849275
# epochs: 5  :  loss: 3.339257244807076
# epochs: 6  :  loss: 3.205182338717596
# epochs: 292  :  loss: 0.6660529401024264
# epochs: 293  :  loss: 0.6660390503024934
# epochs: 294  :  loss: 0.6660253256828269
# epochs: 295  :  loss: 0.6660117636590847
# epochs: 296  :  loss: 0.6659983616900028
# epochs: 297  :  loss: 0.6659851172766621
# epochs: 298  :  loss: 0.6659720279617646

# %%
y_pred.shape
# Out:
# torch.Size([455, 1])

# %%
print(loss)
# Out:
# tensor(0.6654, dtype=torch.float64, grad_fn=<NegBackward0>)

# %%
model.w
# Out:
# tensor([[ 0.1619],
#         [ 0.1709],
#         [ 0.0280],
#         [-0.2805],
#         [-0.0410],
#         [-0.2056],
#         [-0.1784],
#         [ 0.0965],
#         [ 0.0563],
#         [ 0.0284],
#         [-0.1097],
#         [ 0.0879],
#         [-0.0652],
#         [ 0.1106],
#         [-0.0242],
#         [-0.0530],
#         [ 0.0563],
#         [ 0.0279],
#         [ 0.1078],
#         [-0.0395],
#         [-0.0673],
#         [-0.2615],
#         [-0.0247],
#         [ 0.3297],
#         [ 0.1107],
#         [ 0.2797],
#         [ 0.0808],
#         [-0.0972],
#         [-0.1408],
#         [-0.0013]], dtype=torch.float64, requires_grad=True)

# %%
y_pred
# Out:
# tensor([[0.4212],
#         [0.3603],
#         [0.3416],
#         [0.3635],
#         [0.3958],
#         [0.4326],
#         [0.3546],
#         [0.3520],
#         [0.3544],
#         [0.4122],
#         [0.3795],
#         [0.3696],
#         [0.3603],
#         [0.3683],
#         [0.3581],
#         [0.4753],
#         [0.3638],
#         [0.3676],
#         [0.4018],
#         [0.3604],
#         [0.3793],
#         [0.4055],
#         [0.3600],
#         [0.3642],
#         [0.3744],
#         [0.3869],
#         [0.3822],
#         [0.4136],
#         [0.3384],
#         [0.3618],
#         [0.3803],
#         [0.3681],
#         [0.3785],
#         [0.4057],
#         [0.3839],
#         [0.3468],
#         [0.4057],
#         [0.3636],
#         [0.3551],
#         [0.3979],
#         [0.4157],
#         [0.4029],
#         [0.3692],
#         [0.3753],
#         [0.3768],
#         [0.3685],
#         [0.3590],
#         [0.4524],
#         [0.4005],
#         [0.3376],
#         [0.3818],
#         [0.3535],
#         [0.3646],
#         [0.3527],
#         [0.4212],
#         [0.3992],
#         [0.3020],
#         [0.3643],
#         [0.3623],
#         [0.3956],
#         [0.3999],
#         [0.3653],
#         [0.3871],
#         [0.4040],
#         [0.4022],
#         [0.4472],
#         [0.3245],
#         [0.3317],
#         [0.4029],
#         [0.3617],
#         [0.3456],
#         [0.3798],
#         [0.4112],
#         [0.3800],
#         [0.3785],
#         [0.3443],
#         [0.3523],
#         [0.3890],
#         [0.3767],
#         [0.4382],
#         [0.3567],
#         [0.3765],
#         [0.3798],
#         [0.3910],
#         [0.3510],
#         [0.3932],
#         [0.3555],
#         [0.3474],
#         [0.3317],
#         [0.3884],
#         [0.3580],
#         [0.4060],
#         [0.3628],
#         [0.3410],
#         [0.3269],
#         [0.3699],
#         [0.3861],
#         [0.4087],
#         [0.3902],
#         [0.3777],
#         [0.3781],
#         [0.4101],
#         [0.4584],
#         [0.3922],
#         [0.3987],
#         [0.3755],
#         [0.3596],
#         [0.3872],
#         [0.3795],
#         [0.4826],
#         [0.5029],
#         [0.3924],
#         [0.4044],
#         [0.3351],
#         [0.4288],
#         [0.3816],
#         [0.3680],
#         [0.3616],
#         [0.3595],
#         [0.3459],
#         [0.3839],
#         [0.3787],
#         [0.3673],
#         [0.3690],
#         [0.4115],
#         [0.3857],
#         [0.4482],
#         [0.4057],
#         [0.3934],
#         [0.3608],
#         [0.3595],
#         [0.3372],
#         [0.3446],
#         [0.3767],
#         [0.3426],
#         [0.3917],
#         [0.4178],
#         [0.3516],
#         [0.3874],
#         [0.3753],
#         [0.4280],
#         [0.3637],
#         [0.3704],
#         [0.4138],
#         [0.3251],
#         [0.3892],
#         [0.3136],
#         [0.3594],
#         [0.3695],
#         [0.3905],
#         [0.3703],
#         [0.3933],
#         [0.4049],
#         [0.3599],
#         [0.4962],
#         [0.3396],
#         [0.3958],
#         [0.3620],
#         [0.3538],
#         [0.3647],
#         [0.3866],
#         [0.3394],
#         [0.3743],
#         [0.4014],
#         [0.3379],
#         [0.3608],
#         [0.3773],
#         [0.3497],
#         [0.4395],
#         [0.3668],
#         [0.3717],
#         [0.3932],
#         [0.4153],
#         [0.3839],
#         [0.4036],
#         [0.3590],
#         [0.3625],
#         [0.3860],
#         [0.4178],
#         [0.4128],
#         [0.3851],
#         [0.3748],
#         [0.4118],
#         [0.3585],
#         [0.4130],
#         [0.4687],
#         [0.3991],
#         [0.3874],
#         [0.3810],
#         [0.3969],
#         [0.3432],
#         [0.3523],
#         [0.4011],
#         [0.3834],
#         [0.3415],
#         [0.3704],
#         [0.3736],
#         [0.3684],
#         [0.3735],
#         [0.3282],
#         [0.3760],
#         [0.3684],
#         [0.4710],
#         [0.3574],
#         [0.4155],
#         [0.3733],
#         [0.3689],
#         [0.3683],
#         [0.3834],
#         [0.4224],
#         [0.3931],
#         [0.3687],
#         [0.4226],
#         [0.4915],
#         [0.3510],
#         [0.3837],
#         [0.4143],
#         [0.3633],
#         [0.3835],
#         [0.3673],
#         [0.3869],
#         [0.3765],
#         [0.3770],
#         [0.4038],
#         [0.3600],
#         [0.3638],
#         [0.3849],
#         [0.3916],
#         [0.3501],
#         [0.3770],
#         [0.2954],
#         [0.3668],
#         [0.3868],
#         [0.3419],
#         [0.3713],
#         [0.3787],
#         [0.3723],
#         [0.3434],
#         [0.4977],
#         [0.3939],
#         [0.3466],
#         [0.3708],
#         [0.3690],
#         [0.3992],
#         [0.3758],
#         [0.3771],
#         [0.3753],
#         [0.3475],
#         [0.4103],
#         [0.4005],
#         [0.3824],
#         [0.3913],
#         [0.3733],
#         [0.3815],
#         [0.3431],
#         [0.3489],
#         [0.3997],
#         [0.3741],
#         [0.3838],
#         [0.3546],
#         [0.3569],
#         [0.3470],
#         [0.3709],
#         [0.3819],
#         [0.4367],
#         [0.3568],
#         [0.4209],
#         [0.3580],
#         [0.3506],
#         [0.3822],
#         [0.3589],
#         [0.3662],
#         [0.3904],
#         [0.3973],
#         [0.3234],
#         [0.3737],
#         [0.3925],
#         [0.3612],
#         [0.3864],
#         [0.3898],
#         [0.3601],
#         [0.4139],
#         [0.3419],
#         [0.3835],
#         [0.3905],
#         [0.4123],
#         [0.3593],
#         [0.4499],
#         [0.4248],
#         [0.4013],
#         [0.3579],
#         [0.3804],
#         [0.3330],
#         [0.4068],
#         [0.3985],
#         [0.3689],
#         [0.3937],
#         [0.4046],
#         [0.3554],
#         [0.3538],
#         [0.3664],
#         [0.4109],
#         [0.4372],
#         [0.3645],
#         [0.3780],
#         [0.3649],
#         [0.4060],
#         [0.3933],
#         [0.3933],
#         [0.4631],
#         [0.3970],
#         [0.3928],
#         [0.3526],
#         [0.3717],
#         [0.3631],
#         [0.3581],
#         [0.4118],
#         [0.4027],
#         [0.3799],
#         [0.3351],
#         [0.3904],
#         [0.3695],
#         [0.4289],
#         [0.4342],
#         [0.3412],
#         [0.3786],
#         [0.4103],
#         [0.3850],
#         [0.4119],
#         [0.3387],
#         [0.2701],
#         [0.4047],
#         [0.3851],
#         [0.3715],
#         [0.3855],
#         [0.3489],
#         [0.3588],
#         [0.4049],
#         [0.3658],
#         [0.3804],
#         [0.3727],
#         [0.3778],
#         [0.3661],
#         [0.3757],
#         [0.3772],
#         [0.3925],
#         [0.4122],
#         [0.3671],
#         [0.3464],
#         [0.3634],
#         [0.3622],
#         [0.3556],
#         [0.3517],
#         [0.3469],
#         [0.3765],
#         [0.3882],
#         [0.3316],
#         [0.3341],
#         [0.3922],
#         [0.3475],
#         [0.3610],
#         [0.3482],
#         [0.3581],
#         [0.3911],
#         [0.3725],
#         [0.3837],
#         [0.3593],
#         [0.3366],
#         [0.3300],
#         [0.3807],
#         [0.3968],
#         [0.3813],
#         [0.3683],
#         [0.3662],
#         [0.4316],
#         [0.3399],
#         [0.3787],
#         [0.3731],
#         [0.4001],
#         [0.3684],
#         [0.2514],
#         [0.3770],
#         [0.3122],
#         [0.3521],
#         [0.4361],
#         [0.3621],
#         [0.3875],
#         [0.3927],
#         [0.4202],
#         [0.3947],
#         [0.3660],
#         [0.3789],
#         [0.3175],
#         [0.2978],
#         [0.3484],
#         [0.3919],
#         [0.2815],
#         [0.3792],
#         [0.3775],
#         [0.3545],
#         [0.3815],
#         [0.3742],
#         [0.3830],
#         [0.5811],
#         [0.3647],
#         [0.3190],
#         [0.3261],
#         [0.4070],
#         [0.3699],
#         [0.3581],
#         [0.3680],
#         [0.2928],
#         [0.3730],
#         [0.4031],
#         [0.4012],
#         [0.4078],
#         [0.4007],
#         [0.3562],
#         [0.3847],
#         [0.3673],
#         [0.3793],
#         [0.3595],
#         [0.4517],
#         [0.3543],
#         [0.3233],
#         [0.4026],
#         [0.3522],
#         [0.3645],
#         [0.3826],
#         [0.3750],
#         [0.4094],
#         [0.3274],
#         [0.4007],
#         [0.3692],
#         [0.3673],
#         [0.3583],
#         [0.3784],
#         [0.3789],
#         [0.3606],
#         [0.3353],
#         [0.3611],
#         [0.3410],
#         [0.3867],
#         [0.3450],
#         [0.3906],
#         [0.3804],
#         [0.3692],
#         [0.3348],
#         [0.3819],
#         [0.4012],
#         [0.3466],
#         [0.3668],
#         [0.3492],
#         [0.4293],
#         [0.3712]], dtype=torch.float64, grad_fn=<SigmoidBackward0>)

# %%
#Accuracy metrics
with torch.no_grad():
  y_pred=model.forward_pass(X_test_tensor)
  y_pred = (y_pred >0.5).float()
  accuracy = (y_pred==y_test_tensor).float().mean()
  print(f'{accuracy.item()}')
# Out:
# 0.6465066075325012
